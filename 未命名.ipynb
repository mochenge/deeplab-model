# %%
# 进行推理，并展示结果
def run_visualization(url):
    """Inferences DeepLab model and visualizes result."""
    #---------------------------------------------------#
    #    读取网络上某台服务器jpb图片(https://…………)
    #---------------------------------------------------#
    # try:
    #     f = urllib.request.urlopen(url)
    #     jpeg_str = f.read()
    #     original_im = Image.open(BytesIO(jpeg_str))
    # except IOError:
    #     print('Cannot retrieve image. Please check url: ' + url)
    #     return
    

    #---------------------------------------------------#
    #    读取本地磁盘上jpg图片(disk file)
    #---------------------------------------------------#
    original_im = Image.open(url)
    print('running deeplab on image %s...' % url)
    

    # 模型推理
    resized_im, seg_map = MODEL.run(original_im)
    
    # 可视化显示
    vis_segmentation(resized_im, seg_map)

# %%
 images_dir = 'E:/PycharmProject/datasets/images/'
# images_dir = "E:/PycharmProject/DeepLab_model/datasets/RoadScene/predict_test"
images = sorted(os.listdir(images_dir))
i = 1
for imgfile in images:
    print("Image：" + str(i))
    run_visualization(os.path.join(images_dir, imgfile))
    i += 1

print('Done.')
# Out:
# Image：1
# running deeplab on image E:/PycharmProject/datasets/images/000001.jpg...
# Image：2
# running deeplab on image E:/PycharmProject/datasets/images/000002.jpg...
# Image：3
# running deeplab on image E:/PycharmProject/datasets/images/000003.jpg...
# Image：4
# running deeplab on image E:/PycharmProject/datasets/images/000004.jpg...
# Image：5
# running deeplab on image E:/PycharmProject/datasets/images/000006.jpg...
# Image：6
# running deeplab on image E:/PycharmProject/datasets/images/000008.jpg...
# Image：7
# running deeplab on image E:/PycharmProject/datasets/images/000010.jpg...
# Image：8
# running deeplab on image E:/PycharmProject/datasets/images/000011.jpg...
# Image：9
# running deeplab on image E:/PycharmProject/datasets/images/000013.jpg...
# Done.

# %%
resized_im
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-fe9ebb5cbb0d> in <module>
# ----> 1 resized_im
#
# NameError: name 'resized_im' is not defined

# %%
 resized_im, seg_map = MODEL.run(original_im)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-593e07568c6d> in <module>
# ----> 1 resized_im, seg_map = MODEL.run(original_im)
#
# NameError: name 'original_im' is not defined

# %%
images_dir = "E:/PycharmProject/datasets/images/"
images = sorted(os.listdir(images_dir))
image_name = os.path.join(images_dir, images[0])
img = Image.open(image_name)

# %%
 resized_im, seg_map = MODEL.run(img)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=353x500 at 0x1B95B9A4988>

# %%
resized_im
# Out:
# <PIL.Image.Image image mode=RGB size=362x513 at 0x1B965DDFB48>

# %%
plt.imshow(seg_map)

# %%
unique_labels = np.unique(seg_map)

# %%
unique_labels
# Out:
# array([ 0, 12, 15], dtype=int64)
